# %% [markdown]
# # Programming For Analytics
# ##### © Pratik Agrawal, 2016
#
# ## Combining Data, Transforming, and Graphing
# - Combining Data
#  - `shape`
#  - `concat()`
#  - `merge()`
# - Transforming
#  - `lambda`
#  - `apply()`
#  - `applymap()`
#  - `groupby()`
# - Graphing
#  - `matplotlib`
#  - `plot()`
#    - line plot
#      - plot against indices
#      - multiple data sets
#    - launching plot inline/separate window
#    - plot format strings
#    - scatter plots
#    - multiple plot windows
#    - multiple plots in one window
#    - legend
#    - titles and grid
#  - histograms
#  - `seaborn`
# - Exercises!
#
#
# ## Combining Data
# ### 1. `shape`
# We had a brief look at `dataframes` from `pandas` in the last class. Lets look at how we can find out the number of rows and columns in a given data set. Lets first discover the files `../data/aapl*`

# %%
import glob
files_aapl = glob.glob('/Users/Gian/GitHub/programming-for-analytics-course-material 9.27.13 PM/data/aapl*')

# %%
files_aapl
# Out:
# ['/Users/Gian/GitHub/programming-for-analytics-course-material 9.27.13 PM/data/aapl-1-jan15-oct15.csv',
#  '/Users/Gian/GitHub/programming-for-analytics-course-material 9.27.13 PM/data/aapl-2-jan14-dec14.csv',
#  '/Users/Gian/GitHub/programming-for-analytics-course-material 9.27.13 PM/data/aapl-3-dec80-dec13.csv']

# %% [markdown]
# Lets now read each of these files into a list using `pandas read_csv()`

# %%
import pandas as pd

# %%
# We create ONE list with 3 different columns. Each column relates to each entire file.
list_of_aapl_df = []
for i in files_aapl:
    j = pd.read_csv(i,infer_datetime_format = True)
    list_of_aapl_df.append(j)

# %% [markdown]
# Lets take a look at each of the files that were read in-

# %%
# This selects Year 2015 file
list_of_aapl_df[0].head()
# Out:
#          Date        Open        High         Low       Close    Volume  \
# 0  2015-10-21  114.000000  115.580002  113.699997  113.760002  41795200
# 1  2015-10-20  111.339996  114.169998  110.820000  113.769997  48778800
# 2  2015-10-19  110.800003  111.750000  110.110001  111.730003  29606100
# 3  2015-10-16  111.779999  112.000000  110.529999  111.040001  38236300
# 4  2015-10-15  110.930000  112.099998  110.489998  111.860001  37341000
#
#     Adj Close
# 0  113.760002
# 1  113.769997
# 2  111.730003
# 3  111.040001
# 4  111.860001

# %%
# This selects Year 2014 file
list_of_aapl_df[1].head()
# Out:
#          Date        Open        High         Low       Close    Volume  \
# 0  2014-12-31  112.820000  113.129997  110.209999  110.379997  41403400
# 1  2014-12-30  113.639999  113.919998  112.110001  112.519997  29881500
# 2  2014-12-29  113.790001  114.769997  113.699997  113.910004  27598900
# 3  2014-12-26  112.099998  114.519997  112.010002  113.989998  33721000
# 4  2014-12-24  112.580002  112.709999  112.010002  112.010002  14479600
#
#     Adj Close
# 0  108.995380
# 1  111.108535
# 2  112.481106
# 3  112.560096
# 4  110.604938

# %%
# This selects Year 2013 file
list_of_aapl_df[2].head()
# Out:
#          Date        Open        High         Low       Close    Volume  \
# 0  2013-12-31  554.170013  561.279976  554.000023  561.019997  55771100
# 1  2013-12-30  557.460022  560.089989  552.319984  554.519981  63407400
# 2  2013-12-27  563.820007  564.409981  559.500015  560.089989  56471100
# 3  2013-12-26  568.099998  569.499977  563.379997  563.900009  51002000
# 4  2013-12-24  569.889999  571.880005  566.029991  567.669975  41888700
#
#    Adj Close
# 0  77.509204
# 1  76.611177
# 2  77.380716
# 3  77.907099
# 4  78.427949

# %% [markdown]
# Can we call `head()` on the variable `list_of_aapl_df` ?

# %%
# No we can't do head() on a list
list_of_aapl_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e60e0a8960c1> in <module>()
# ----> 1 list_of_aapl_df.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %% [markdown]
# So far we have been able to confirm that this is the required data. We should now check the dimensions of this data set-

# %%
# .shape says how many rows and columns. This is a tuple, btw, since list_of_aapl_df is a list
list_of_aapl_df[0].shape
# Out:
# (203, 7)

# %%
list_of_aapl_df[1].shape
# Out:
# (252, 7)

# %%
list_of_aapl_df[2].shape
# Out:
# (8336, 7)

# %% [markdown]
# ### 2. `concat()`
# In the last assignment you had to write a lot of code to probably concatenate the three files together. Lets see a simpler way to concatenate all the data frames-

# %%
aapl_df = pd.concat(list_of_aapl_df)
aapl_df.head()
# Out:
#          Date        Open        High         Low       Close    Volume  \
# 0  2015-10-21  114.000000  115.580002  113.699997  113.760002  41795200
# 1  2015-10-20  111.339996  114.169998  110.820000  113.769997  48778800
# 2  2015-10-19  110.800003  111.750000  110.110001  111.730003  29606100
# 3  2015-10-16  111.779999  112.000000  110.529999  111.040001  38236300
# 4  2015-10-15  110.930000  112.099998  110.489998  111.860001  37341000
#
#     Adj Close
# 0  113.760002
# 1  113.769997
# 2  111.730003
# 3  111.040001
# 4  111.860001

# %% [markdown]
# Lets confirm that all the data was concatenated-

# %%
# this concatenated list 1, list 2, and list 3 all into one data frame
aapl_df.shape
# Out:
# (8791, 7)

# %% [markdown]
# What if we had read in the files into separate variables-

# %%
# we are creating data frames for each year based off the lists
df_aapl_1 = list_of_aapl_df[0]

# %%
df_aapl_2 = list_of_aapl_df[1]

# %%
df_aapl_3 = list_of_aapl_df[2]

# %% [markdown]
# Now we have to concatenate all these files. In order to do this you must remember that `concat()` function accepts a list of variables only, and not individual variables-

# %%
# concatenate...but they're not lists. MUST BE LIST to concatenate
aapl_df = pd.concat(df_aapl_1, df_aapl_2, df_aapl_3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a871dc7fcf21> in <module>()
#       1 # concatenate
# ----> 2 aapl_df = pd.concat(df_aapl_1, df_aapl_2, df_aapl_3)
#
# /Users/Gian/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     832                        keys=keys, levels=levels, names=names,
#     833                        verify_integrity=verify_integrity,
# --> 834                        copy=copy)
#     835     return op.get_result()
#     836
#
# /Users/Gian/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     847             raise TypeError('first argument must be an iterable of pandas '
#     848                             'objects, you passed an object of type '
# --> 849                             '"{0}"'.format(type(objs).__name__))
#     850
#     851         if join == 'outer':
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
# the brackets turned data frames into a list in order to be concatenated...now final file is a data frame
aapl_df = pd.concat([df_aapl_1, df_aapl_2, df_aapl_3])
aapl_df.head()
# Out:
#          Date        Open        High         Low       Close    Volume  \
# 0  2015-10-21  114.000000  115.580002  113.699997  113.760002  41795200
# 1  2015-10-20  111.339996  114.169998  110.820000  113.769997  48778800
# 2  2015-10-19  110.800003  111.750000  110.110001  111.730003  29606100
# 3  2015-10-16  111.779999  112.000000  110.529999  111.040001  38236300
# 4  2015-10-15  110.930000  112.099998  110.489998  111.860001  37341000
#
#     Adj Close
# 0  113.760002
# 1  113.769997
# 2  111.730003
# 3  111.040001
# 4  111.860001

# %%
aapl_df.shape
# Out:
# (8791, 7)

# %% [markdown]
# ### 3. `merge()`
# Up until now we have seen how to concatenate data along an axis. What if we have to join the files on an variable/column.
#
# Lets read in the Divvy data set files

# %%
# Warning states that columns have different data types so panda cannot tell what kind of data to classify the data as
df_trips=pd.read_csv("/Users/Gian/GitHub/programming-for-analytics-course-material 9.27.13 PM/data/Divvy_Trips_2013.csv", infer_datetime_format=True)
df_stations=pd.read_csv("/Users/Gian/GitHub/programming-for-analytics-course-material 9.27.13 PM/data/Divvy_Stations_2013.csv")
# Out:
# /Users/Gian/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# #### Lets take a quick peek at the head for each data frame
# *Remember that the head function has a default n=5. Which implies that it displays only the first 5 rows of the dataframe*

# %%
df_trips.head()
# Out:
#    trip_id         starttime          stoptime  bikeid  tripduration  \
# 0     4118  2013-06-27 12:11  2013-06-27 12:16     480           316
# 1     4275  2013-06-27 14:44  2013-06-27 14:45      77            64
# 2     4291  2013-06-27 14:58  2013-06-27 15:05      77           433
# 3     4316  2013-06-27 15:06  2013-06-27 15:09      77           123
# 4     4342  2013-06-27 15:13  2013-06-27 15:27      77           852
#
#    from_station_id           from_station_name  to_station_id  \
# 0               85       Michigan Ave & Oak St             28
# 1               32  Racine Ave & Congress Pkwy             32
# 2               32  Racine Ave & Congress Pkwy             19
# 3               19       Loomis St & Taylor St             19
# 4               19       Loomis St & Taylor St             55
#
#                     to_station_name  usertype gender  birthday
# 0        Larrabee St & Menomonee St  Customer    NaN       NaN
# 1        Racine Ave & Congress Pkwy  Customer    NaN       NaN
# 2             Loomis St & Taylor St  Customer    NaN       NaN
# 3             Loomis St & Taylor St  Customer    NaN       NaN
# 4  Halsted St & James M Rochford St  Customer    NaN       NaN

# %%
df_stations.head()
# Out:
#    id                        name   latitude  longitude  dpcapacity  landmark  \
# 0   5      State St & Harrison St  41.873958 -87.627739          19        30
# 1  13  Wilton Ave & Diversey Pkwy  41.932500 -87.652681          19        66
# 2  14         Morgan St & 18th St  41.858086 -87.651073          15       163
# 3  15        Racine Ave & 18th St  41.858181 -87.656487          15       164
# 4  16         Wood St & North Ave  41.910329 -87.672516          15       223
#
#   online date
# 0   6/28/2013
# 1   6/28/2013
# 2   6/28/2013
# 3   6/28/2013
# 4   8/12/2013

# %%
# we have two data sets of divy bikes from Chicago public bikes and bike stations. Let's look at the columns in trips
# This is faster than just using head() to see column names. 
# We are converting it into a list. Otherwise it would be an array
cols_trips = list(df_trips.columns)
cols_trips
# Out:
# ['trip_id',
#  'starttime',
#  'stoptime',
#  'bikeid',
#  'tripduration',
#  'from_station_id',
#  'from_station_name',
#  'to_station_id',
#  'to_station_name',
#  'usertype',
#  'gender',
#  'birthday']

# %%
cols_stations = list(df_stations.columns)
cols_stations
# Out:
# ['id',
#  'name',
#  'latitude',
#  'longitude',
#  'dpcapacity',
#  'landmark',
#  'online date']

# %% [markdown]
# #### Join Number 1
# Both *from* and *to* station ids in the trips dataset have static data in the second table (stations). In order to run calculations and google maps api queries etc. we need to join first for the *from_station_id* and second for the *to_station_id*
#
# ##### First lets check the shape of the trips dataset

# %%
# Show (rows, cols) of trips data
df_trips.shape
# Out:
# (759788, 12)

# %% [markdown]
# ##### Now lets run the merge/join operation, and store the result in a new df

# %%
# is a join. does not specify what kind of join. Left is df_trips and Right is df_stations. 
# we are joining where from_station_id = id
# DEFAULT is inner join. Otherwise do how='inner', 'left' (left outer join), 'right' (right outer join), 'outer' (full outer join)
df_from=pd.merge(df_trips,df_stations,left_on="from_station_id",right_on="id")

# %%
# We can subset data so we can create specific criteria before we join
# df_trips.bikeid==77 creates a TRUE/FALSE list...then the brackets will show only rows where list = TRUE
df_trips[df_trips.bikeid==77]
# Out:
#         trip_id         starttime          stoptime  bikeid  tripduration  \
# 1          4275  2013-06-27 14:44  2013-06-27 14:45      77            64
# 2          4291  2013-06-27 14:58  2013-06-27 15:05      77           433
# 3          4316  2013-06-27 15:06  2013-06-27 15:09      77           123
# 4          4342  2013-06-27 15:13  2013-06-27 15:27      77           852
# 1207       9008  2013-06-29 17:39  2013-06-29 17:59      77          1254
# 1316       9205  2013-06-29 18:44  2013-06-29 18:55      77           617
# 1434       9459  2013-06-29 20:24  2013-06-29 20:32      77           477
# 41210     99139  2013-07-23 22:18  2013-07-23 22:31      77           756
# 41745    101289  2013-07-24 14:08  2013-07-24 14:46      77          2333
# 41882    101755  2013-07-24 15:42  2013-07-24 16:01      77          1151
# 45554    112403  2013-07-27 02:27  2013-07-27 11:34      77         32810
# 46026    113433  2013-07-27 11:51  2013-07-27 12:16      77          1508
# 48512    117934  2013-07-28 11:10  2013-07-28 11:27      77          1069
# 50036    120505  2013-07-28 17:38  2013-07-28 18:09      77          1891
# 52876    128358  2013-07-30 11:48  2013-07-30 12:02      77           856
# 52910    128424  2013-07-30 12:03  2013-07-30 12:28      77          1476
# 53080    128984  2013-07-30 14:42  2013-07-30 14:53      77           695
# 53745    131546  2013-07-31 09:49  2013-07-31 09:54      77           313
# 53869    132018  2013-07-31 12:15  2013-07-31 12:33      77          1105
# 53944    132314  2013-07-31 13:07  2013-07-31 13:30      77          1324
# 56759    141006  2013-08-02 09:18  2013-08-02 09:33      77           865
# 59687    147537  2013-08-03 12:51  2013-08-03 13:05      77           839
# 60061    148103  2013-08-03 13:40  2013-08-03 14:25      77          2672
# 60465    148742  2013-08-03 14:33  2013-08-03 14:45      77           734
# 61301    150171  2013-08-03 16:42  2013-08-03 16:52      77           565
# 62894    152788  2013-08-03 21:36  2013-08-03 21:52      77           955
# 63297    153496  2013-08-04 00:04  2013-08-04 00:38      77          2045
# 63439    153737  2013-08-04 03:02  2013-08-04 03:22      77          1193
# 63474    153796  2013-08-04 04:42  2013-08-04 05:04      77          1294
# 63866    154649  2013-08-04 10:42  2013-08-04 11:11      77          1729
# ...         ...               ...               ...     ...           ...
# 682777   181241  2013-08-08 16:20  2013-08-08 16:31      77           646
# 683357   191945  2013-08-10 08:23  2013-08-10 08:37      77           835
# 683629   198880  2013-08-10 18:44  2013-08-10 18:59      77           922
# 683635   199093  2013-08-10 19:03  2013-08-10 19:23      77          1158
# 687622   278597  2013-08-20 19:09  2013-08-20 19:29      77          1184
# 687678   279194  2013-08-20 20:13  2013-08-20 20:35      77          1320
# 688988   296795  2013-08-23 12:03  2013-08-23 12:20      77          1044
# 689385   303552  2013-08-24 01:00  2013-08-24 01:27      77          1579
# 691600   344281  2013-08-28 13:42  2013-08-28 13:55      77           818
# 691915   348168  2013-08-28 21:10  2013-08-28 21:15      77           316
# 697681   445197  2013-09-08 12:59  2013-09-08 13:13      77           879
# 699253   464062  2013-09-10 17:49  2013-09-10 18:03      77           849
# 699356   464789  2013-09-10 18:57  2013-09-10 19:19      77          1310
# 701600   486951  2013-09-13 16:26  2013-09-13 16:48      77          1352
# 702945   505884  2013-09-16 08:19  2013-09-16 08:26      77           395
# 704050   517445  2013-09-17 16:06  2013-09-17 16:19      77           751
# 704227   518874  2013-09-17 17:43  2013-09-17 17:57      77           792
# 704388   520024  2013-09-17 19:22  2013-09-17 19:27      77           330
# 710513   589696  2013-09-25 18:55  2013-09-25 19:01      77           321
# 711360   598284  2013-09-26 17:55  2013-09-26 18:02      77           391
# 722349   724874  2013-10-09 14:46  2013-10-09 15:10      77          1490
# 734752   859256  2013-10-25 12:05  2013-10-25 12:11      77           349
# 742794   935505  2013-11-07 09:41  2013-11-07 10:01      77          1212
# 750266  1008597  2013-11-21 11:14  2013-11-21 11:18      77           194
# 750278  1008701  2013-11-21 11:38  2013-11-21 11:42      77           213
# 751244  1017661  2013-11-23 16:24  2013-11-23 16:31      77           445
# 755883  1061311  2013-12-07 04:01  2013-12-07 04:12      77           677
# 755992  1062495  2013-12-07 14:25  2013-12-07 14:31      77           382
# 758376  1091765  2013-12-20 11:36  2013-12-20 11:42      77           379
# 758554  1093862  2013-12-21 09:26  2013-12-21 09:42      77           979
#
#         from_station_id                    from_station_name  to_station_id  \
# 1                    32           Racine Ave & Congress Pkwy             32
# 2                    32           Racine Ave & Congress Pkwy             19
# 3                    19                Loomis St & Taylor St             19
# 4                    19                Loomis St & Taylor St             55
# 1207                 27              Larrabee St & North Ave             27
# 1316                 27              Larrabee St & North Ave             93
# 1434                 93            Sheffield Ave & Willow St             62
# 41210               181             LaSalle St & Illinois St             25
# 41745                85                Michigan Ave & Oak St             34
# 41882                34            Cannon Dr & Fullerton Ave             85
# 45554                29             Noble St & Milwaukee Ave             94
# 46026                94           Lincoln Ave & Armitage Ave             99
# 48512                75              Canal St & Jackson Blvd             72
# 50036                72                   State St & 16th St            169
# 52876                75              Canal St & Jackson Blvd             47
# 52910                47                 State St & Kinzie St            126
# 53080               126                 Clark St & North Ave             34
# 53745                94           Lincoln Ave & Armitage Ave             94
# 53869                94           Lincoln Ave & Armitage Ave             56
# 53944                56            Desplaines St & Kinzie St            252
# 56759                80             Aberdeen St & Madison St             47
# 59687                92              Carpenter St & Huron St             97
# 60061                97                        Museum Campus             97
# 60465                97                        Museum Campus             59
# 61301                37               Dearborn St & Adams St            175
# 62894                59            Wabash Ave & Roosevelt Rd             72
# 63297                72                   State St & 16th St            118
# 63439               118              Sedgwick St & North Ave             67
# 63474                67        Sheffield Ave & Fullerton Ave             69
# 63866                90                      Millennium Park             90
# ...                 ...                                  ...            ...
# 682777               58           Ashland Ave & Armitage Ave            166
# 683357              166         Ashland Ave & Wrightwood Ave             20
# 683629               20         Sheffield Ave & Kingsbury St             56
# 683635               56            Desplaines St & Kinzie St             90
# 687622              185              Stave St & Armitage Ave            144
# 687678              144            Larrabee St & Webster Ave            185
# 688988               48           Larrabee St & Kingsbury St             35
# 689385              114           Sheffield Ave & Addison St            114
# 691600               74               Kingsbury St & Erie St            192
# 691915               24             Fairbanks Ct & Grand Ave             35
# 697681              114           Sheffield Ave & Addison St            231
# 699253              212                   Wells St & Ohio St            173
# 699356              173  Mies van der Rohe Way & Chicago Ave            126
# 701600              100  Orleans St & Merchandise Mart Plaza             59
# 702945               91         Clinton St & Washington Blvd             81
# 704050              175                   Wells St & Polk St             80
# 704227               80             Aberdeen St & Madison St            175
# 704388              175                   Wells St & Polk St             37
# 710513               67        Sheffield Ave & Fullerton Ave            152
# 711360              134             Peoria St & Jackson Blvd             36
# 722349              242               Damen Ave & Leland Ave            123
# 734752              100  Orleans St & Merchandise Mart Plaza            110
# 742794              333           Ashland Ave & Blackhawk St            192
# 750266              255           Indiana Ave & Roosevelt Rd            321
# 750278              321                  Wabash Ave & 8th St            255
# 751244               31            Franklin St & Chicago Ave             54
# 755883              232          Pine Grove Ave & Addison St            229
# 755992              229            Southport Ave & Roscoe St            318
# 758376               22                   May St & Taylor St            261
# 758554               94           Lincoln Ave & Armitage Ave            164
#
#                             to_station_name    usertype  gender  birthday
# 1                Racine Ave & Congress Pkwy    Customer     NaN       NaN
# 2                     Loomis St & Taylor St    Customer     NaN       NaN
# 3                     Loomis St & Taylor St    Customer     NaN       NaN
# 4          Halsted St & James M Rochford St    Customer     NaN       NaN
# 1207                Larrabee St & North Ave    Customer     NaN       NaN
# 1316              Sheffield Ave & Willow St    Customer     NaN       NaN
# 1434                        McCormick Place    Customer     NaN       NaN
# 41210             Michigan Ave & Pearson St    Customer     NaN       NaN
# 41745             Cannon Dr & Fullerton Ave    Customer     NaN       NaN
# 41882                 Michigan Ave & Oak St    Customer     NaN       NaN
# 45554            Lincoln Ave & Armitage Ave    Customer     NaN       NaN
# 46026               Lake Shore Dr & Ohio St    Customer     NaN       NaN
# 48512                    State St & 16th St    Customer     NaN       NaN
# 50036                Canal St & Harrison St    Customer     NaN       NaN
# 52876                  State St & Kinzie St    Customer     NaN       NaN
# 52910                  Clark St & North Ave    Customer     NaN       NaN
# 53080             Cannon Dr & Fullerton Ave    Customer     NaN       NaN
# 53745            Lincoln Ave & Armitage Ave    Customer     NaN       NaN
# 53869             Desplaines St & Kinzie St    Customer     NaN       NaN
# 53944               Greenwood Ave & 47th St    Customer     NaN       NaN
# 56759                  State St & Kinzie St    Customer     NaN       NaN
# 59687                         Museum Campus    Customer     NaN       NaN
# 60061                         Museum Campus    Customer     NaN       NaN
# 60465             Wabash Ave & Roosevelt Rd    Customer     NaN       NaN
# 61301                    Wells St & Polk St    Customer     NaN       NaN
# 62894                    State St & 16th St    Customer     NaN       NaN
# 63297               Sedgwick St & North Ave    Customer     NaN       NaN
# 63439         Sheffield Ave & Fullerton Ave    Customer     NaN       NaN
# 63474                Damen Ave & Pierce Ave    Customer     NaN       NaN
# 63866                       Millennium Park    Customer     NaN       NaN
# ...                                     ...         ...     ...       ...
# 682777         Ashland Ave & Wrightwood Ave  Subscriber  Female    1989.0
# 683357         Sheffield Ave & Kingsbury St  Subscriber  Female    1986.0
# 683629            Desplaines St & Kinzie St  Subscriber  Female    1976.0
# 683635                      Millennium Park  Subscriber  Female    1976.0
# 687622            Larrabee St & Webster Ave  Subscriber  Female    1987.0
# 687678              Stave St & Armitage Ave  Subscriber  Female    1987.0
# 688988            Streeter Dr & Illinois St  Subscriber  Female    1984.0
# 689385           Sheffield Ave & Addison St  Subscriber  Female    1988.0
# 691600                  Canal St & Adams St  Subscriber  Female    1975.0
# 691915            Streeter Dr & Illinois St  Subscriber  Female    1983.0
# 697681           Sheridan Rd & Montrose Ave  Subscriber  Female    1989.0
# 699253  Mies van der Rohe Way & Chicago Ave  Subscriber  Female    1987.0
# 699356                 Clark St & North Ave  Subscriber  Female    1987.0
# 701600            Wabash Ave & Roosevelt Rd  Subscriber  Female    1981.0
# 702945                   Daley Center Plaza  Subscriber  Female    1980.0
# 704050             Aberdeen St & Madison St  Subscriber  Female    1969.0
# 704227                   Wells St & Polk St  Subscriber  Female    1969.0
# 704388               Dearborn St & Adams St  Subscriber  Female    1984.0
# 710513          Lincoln Ave & Diversey Pkwy  Subscriber  Female    1968.0
# 711360           Franklin St & Jackson Blvd  Subscriber  Female    1959.0
# 722349       California Ave & Milwaukee Ave  Subscriber  Female    1971.0
# 734752                   State St & Erie St  Subscriber  Female    1962.0
# 742794                  Canal St & Adams St  Subscriber  Female    1983.0
# 750266                  Wabash Ave & 8th St  Subscriber  Female    1994.0
# 750278           Indiana Ave & Roosevelt Rd  Subscriber  Female    1994.0
# 751244              Ogden Ave & Chicago Ave  Subscriber  Female    1990.0
# 755883            Southport Ave & Roscoe St  Subscriber  Female    1990.0
# 755992       Southport Ave & Irving Park Rd  Subscriber  Female    1966.0
# 758376              Hermitage Ave & Polk St  Subscriber  Female    1984.0
# 758554                Franklin St & Lake St  Subscriber  Female    1951.0
#
# [393 rows x 12 columns]

# %%
# how big is this subset?
df_trips[df_trips.bikeid==77].shape
# Out:
# (393, 12)

# %%
df_from_77 = pd.merge(df_trips[df_trips.bikeid==77],df_stations,left_on="from_station_id",right_on="id")

# %%
df_from_77.head()
# Out:
#    trip_id         starttime          stoptime  bikeid  tripduration  \
# 0     4275  2013-06-27 14:44  2013-06-27 14:45      77            64
# 1     4291  2013-06-27 14:58  2013-06-27 15:05      77           433
# 2     4316  2013-06-27 15:06  2013-06-27 15:09      77           123
# 3     4342  2013-06-27 15:13  2013-06-27 15:27      77           852
# 4   356027  2013-08-29 21:02  2013-08-29 21:26      77          1420
#
#    from_station_id           from_station_name  to_station_id  \
# 0               32  Racine Ave & Congress Pkwy             32
# 1               32  Racine Ave & Congress Pkwy             19
# 2               19       Loomis St & Taylor St             19
# 3               19       Loomis St & Taylor St             55
# 4               19       Loomis St & Taylor St            168
#
#                     to_station_name  usertype gender  birthday  id  \
# 0        Racine Ave & Congress Pkwy  Customer    NaN       NaN  32
# 1             Loomis St & Taylor St  Customer    NaN       NaN  32
# 2             Loomis St & Taylor St  Customer    NaN       NaN  19
# 3  Halsted St & James M Rochford St  Customer    NaN       NaN  19
# 4            Michigan Ave & 14th St  Customer    NaN       NaN  19
#
#                          name   latitude  longitude  dpcapacity  landmark  \
# 0  Racine Ave & Congress Pkwy  41.874640 -87.657030          19        76
# 1  Racine Ave & Congress Pkwy  41.874640 -87.657030          19        76
# 2       Loomis St & Taylor St  41.869417 -87.660996          15       139
# 3       Loomis St & Taylor St  41.869417 -87.660996          15       139
# 4       Loomis St & Taylor St  41.869417 -87.660996          15       139
#
#   online date
# 0   6/28/2013
# 1   6/28/2013
# 2   6/28/2013
# 3   6/28/2013
# 4   6/28/2013

# %%
# ?pd.merge

# %% [markdown]
# ##### Lets check the shape again

# %%
df_from.shape
# Out:
# (759788, 19)

# %%
# This is another subset idea
df_trips[["from_station_id","to_station_id"]]
# Out:
#         from_station_id  to_station_id
# 0                    85             28
# 1                    32             32
# 2                    32             19
# 3                    19             19
# 4                    19             55
# 5                   340             46
# 6                    37             76
# 7                    90             75
# 8                    37             37
# 9                    51            340
# 10                   44             44
# 11                   24             24
# 12                   20             46
# 13                   52             52
# 14                   52             52
# 15                   44             52
# 16                   69             29
# 17                   61             17
# 18                   85             85
# 19                   85             85
# 20                   61             17
# 21                   61             17
# 22                   61             16
# 23                   61             16
# 24                   85             85
# 25                   85             85
# 26                   85             85
# 27                   17             61
# 28                   67            348
# 29                   67             34
# ...                 ...            ...
# 759758               66             66
# 759759              232            304
# 759760               66            140
# 759761               31            192
# 759762               33             49
# 759763              185            123
# 759764               20             16
# 759765               52            211
# 759766              250            153
# 759767              344            314
# 759768              284             59
# 759769              153            115
# 759770               73            181
# 759771              350             31
# 759772               81            175
# 759773               31            110
# 759774               49            175
# 759775              181             73
# 759776               49             59
# 759777               26             56
# 759778              110            176
# 759779               50            170
# 759780              214            285
# 759781              234            318
# 759782               60             20
# 759783               20             93
# 759784              227            228
# 759785              284             43
# 759786              130             69
# 759787              216             69
#
# [759788 rows x 2 columns]

# %%
df_from.head()
# Out:
#    trip_id         starttime          stoptime  bikeid  tripduration  \
# 0     4118  2013-06-27 12:11  2013-06-27 12:16     480           316
# 1     4865  2013-06-27 22:16  2013-06-27 22:42     343          1511
# 2     4866  2013-06-27 22:17  2013-06-27 22:42     220          1512
# 3     4883  2013-06-27 22:26  2013-06-27 23:04     221          2272
# 4     4896  2013-06-27 22:33  2013-06-27 23:05     409          1911
#
#    from_station_id      from_station_name  to_station_id  \
# 0               85  Michigan Ave & Oak St             28
# 1               85  Michigan Ave & Oak St             85
# 2               85  Michigan Ave & Oak St             85
# 3               85  Michigan Ave & Oak St             85
# 4               85  Michigan Ave & Oak St             85
#
#               to_station_name  usertype gender  birthday  id  \
# 0  Larrabee St & Menomonee St  Customer    NaN       NaN  85
# 1       Michigan Ave & Oak St  Customer    NaN       NaN  85
# 2       Michigan Ave & Oak St  Customer    NaN       NaN  85
# 3       Michigan Ave & Oak St  Customer    NaN       NaN  85
# 4       Michigan Ave & Oak St  Customer    NaN       NaN  85
#
#                     name  latitude  longitude  dpcapacity  landmark  \
# 0  Michigan Ave & Oak St  41.90096 -87.623777          15        42
# 1  Michigan Ave & Oak St  41.90096 -87.623777          15        42
# 2  Michigan Ave & Oak St  41.90096 -87.623777          15        42
# 3  Michigan Ave & Oak St  41.90096 -87.623777          15        42
# 4  Michigan Ave & Oak St  41.90096 -87.623777          15        42
#
#   online date
# 0   6/28/2013
# 1   6/28/2013
# 2   6/28/2013
# 3   6/28/2013
# 4   6/28/2013

# %% [markdown]
# #### Join Number 2

# %%
df_divvy=pd.merge(df_from,df_stations,left_on="to_station_id",right_on="id")
# Other join was creationg df_from
# df_from=pd.merge(df_trips,df_stations,left_on="from_station_id",right_on="id")

# %% [markdown]
# ##### Lets check the shape again

# %%
df_divvy.shape
# Out:
# (759788, 26)

# %%
df_divvy.head()
# Out:
#    trip_id         starttime          stoptime  bikeid  tripduration  \
# 0     4118  2013-06-27 12:11  2013-06-27 12:16     480           316
# 1     5883  2013-06-28 12:55  2013-06-28 13:18     176          1368
# 2    42757  2013-07-09 19:06  2013-07-09 19:31     373          1480
# 3    42759  2013-07-09 19:07  2013-07-09 19:31      13          1469
# 4    48467  2013-07-11 12:24  2013-07-11 12:46     735          1330
#
#    from_station_id      from_station_name  to_station_id  \
# 0               85  Michigan Ave & Oak St             28
# 1               85  Michigan Ave & Oak St             28
# 2               85  Michigan Ave & Oak St             28
# 3               85  Michigan Ave & Oak St             28
# 4               85  Michigan Ave & Oak St             28
#
#               to_station_name  usertype      ...       dpcapacity_x  \
# 0  Larrabee St & Menomonee St  Customer      ...                 15
# 1  Larrabee St & Menomonee St  Customer      ...                 15
# 2  Larrabee St & Menomonee St  Customer      ...                 15
# 3  Larrabee St & Menomonee St  Customer      ...                 15
# 4  Larrabee St & Menomonee St  Customer      ...                 15
#
#    landmark_x  online date_x id_y                      name_y  latitude_y  \
# 0          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
# 1          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
# 2          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
# 3          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
# 4          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
#
#    longitude_y  dpcapacity_y landmark_y  online date_y
# 0    -87.64332            15        282      6/28/2013
# 1    -87.64332            15        282      6/28/2013
# 2    -87.64332            15        282      6/28/2013
# 3    -87.64332            15        282      6/28/2013
# 4    -87.64332            15        282      6/28/2013
#
# [5 rows x 26 columns]

# %%
# list all column names
list(df_divvy.columns)
# Out:
# ['trip_id',
#  'starttime',
#  'stoptime',
#  'bikeid',
#  'tripduration',
#  'from_station_id',
#  'from_station_name',
#  'to_station_id',
#  'to_station_name',
#  'usertype',
#  'gender',
#  'birthday',
#  'id_x',
#  'name_x',
#  'latitude_x',
#  'longitude_x',
#  'dpcapacity_x',
#  'landmark_x',
#  'online date_x',
#  'id_y',
#  'name_y',
#  'latitude_y',
#  'longitude_y',
#  'dpcapacity_y',
#  'landmark_y',
#  'online date_y']

# %% [markdown]
# #### Note that *pandas* automatically added the suffix \_x and \_y to the column names in conflict. In our example \_x represents details for the *from_station* and \_y represents details for the *to_station*

# %% [markdown]
# ## Transforming
#
# More often than not you will need to clean/transform your data. Running `for` loops is not going to be efficient. We will look at various functions that allow us to clean and transform the data quickly.
#
# ### 1. `lambda`
#
# Q. What is a lambda?
#
# A. the 11th letter of the Greek alphabet
#
# B. the craniometric point at the junction of the sagittal and lamboid sutures of the skull
#
# C. the name of a series of Japanese rocket
#
# D. anonymous (unbound) functions

# %%
import math
 
    # this function has a name
def sqroot(x):
    """
    Finds the square root of the number passed in
    """
    return math.sqrt(x)

# this does not have a name and will be used only one context. lambda input: output
square_rt = lambda x: math.sqrt(x)

# %%
sqroot(49)
# Out:
# 7.0

# %%
# both are the same value
square_rt(49)
# Out:
# 7.0

# %% [markdown]
# Lets read in the sandwiches data set

# %%
df_best_sws = pd.read_csv('/Users/Gian/GitHub/programming-for-analytics-course-material 9.27.13 PM/data/best-sandwiches.csv')

# %%
df_best_sws.head()
# Out:
#    rank           sandwich             restaurant  \
# 0     1                BLT            Old Oak Tap
# 1     2      Fried Bologna              Au Cheval
# 2     3  Woodland Mushroom                   Xoco
# 3     4         Roast Beef        Al&rsquo;s Deli
# 4     5           PB&amp;L  Publican Qualty Meats
#
#                                          description   price  \
# 0  The B is applewood smoked&mdash;nice and snapp...     $10
# 1  Thought your bologna-eating days had retired w...      $9
# 2  Leave it to Rick Bayless and crew to come up w...  $9.50.
# 3  The Francophile brothers behind this deli, whi...  $9.40.
# 4  When this place opened in February, it quickly...     $10
#
#                 address      city         phone                   website  \
# 0  2109 W. Chicago Ave.   Chicago  773-772-0406          theoldoaktap.com
# 1   800 W. Randolph St.   Chicago  312-929-4580       aucheval.tumblr.com
# 2      445 N. Clark St.   Chicago  312-334-3688           rickbayless.com
# 3         914 Noyes St.  Evanston           NaN               alsdeli.net
# 4    825 W. Fulton Mkt.   Chicago  312-445-8977  publicanqualitymeats.com
#
#                     full_address  \
# 0  2109 W. Chicago Ave., Chicago
# 1   800 W. Randolph St., Chicago
# 2      445 N. Clark St., Chicago
# 3        914 Noyes St., Evanston
# 4    825 W. Fulton Mkt., Chicago
#
#                                   formatted_address        lat        lng
# 0  2109 West Chicago Avenue, Chicago, IL 60622, USA  41.895734 -87.679960
# 1  800 West Randolph Street, Chicago, IL 60607, USA  41.884672 -87.647754
# 2    445 North Clark Street, Chicago, IL 60654, USA  41.890602 -87.630925
# 3         914 Noyes Street, Evanston, IL 60201, USA  42.058442 -87.684425
# 4    825 West Fulton Market, Chicago, IL 60607, USA  41.886637 -87.648553

# %% [markdown]
# ### 2. `apply()`
#
# Applies function along input axis of DataFrame.

# %%
# shows first few values for price column
df_best_sws.price.head()
# Out:
# 0       $10
# 1        $9
# 2    $9.50.
# 3    $9.40.
# 4       $10
# Name: price, dtype: object

# %% [markdown]
# Lets get rid of the `$` sign

# %%
# Now we will apply something along entire column. We will take 'price' column and apply function using lambda 
# JUST IN CASE: lambda function is creating a function that has no name. WITHOUT lambda, would apply strip to LIST
# so takes in x and outputs x.strip('$') which strips the value of the $ symbol
# MUCH FASTER THAN ANY FOR LOOP
df_best_sws['price'] = df_best_sws['price'].apply(lambda x: x.strip('$'))
df_best_sws.price.head()
# Out:
# 0       10
# 1        9
# 2    9.50.
# 3    9.40.
# 4       10
# Name: price, dtype: object

# %% [markdown]
# If you notice there are still `.` symbols left in the data. Before we can use this price column for any calculations, we need to clean it up thoroughly.

# %%
# There are still some dots left to remove. STRIP WILL ONLY REMOVE LEADING OR TRAILING THINGS...not things IN BETWEEN
# using ['price'] allows me to read AND write a copy
# using .price gives me ONLY a read only copy
df_best_sws['price'] = df_best_sws['price'].apply(lambda x: x.strip('.'))
df_best_sws.price.head()
# Out:
# 0      10
# 1       9
# 2    9.50
# 3    9.40
# 4      10
# Name: price, dtype: object

# %%
# Shows types of every column (cannot compute things between object and float64) 
# Price is STILL an object after stripping
df_best_sws.dtypes
# Out:
# rank                   int64
# sandwich              object
# restaurant            object
# description           object
# price                 object
# address               object
# city                  object
# phone                 object
# website               object
# full_address          object
# formatted_address     object
# lat                  float64
# lng                  float64
# dtype: object

# %% [markdown]
# ### 3. `applymap()`
#
# Apply a function to a DataFrame that is intended to operate elementwise, i.e. like doing map(func, series) for each series in the DataFrame

# %%
# Create a list of all column names we care about
cols = ['description', 'address', 'sandwich','restaurant','full_address','formatted_address']

# %%
# now returns only columns I'm interested in
df_best_sws[cols]
# Out:
#                                           description  \
# 0   The B is applewood smoked&mdash;nice and snapp...
# 1   Thought your bologna-eating days had retired w...
# 2   Leave it to Rick Bayless and crew to come up w...
# 3   The Francophile brothers behind this deli, whi...
# 4   When this place opened in February, it quickly...
# 5   The mom-and-pop aesthetic is a yeast-scented b...
# 6   In a town that recently discovered the joys of...
# 7   Birchwood&rsquo;s sandwich-slinging virtuosos ...
# 8   Standing three inches high, the Atomica is som...
# 9   Grilled Laughing Bird shrimp and fried oyster ...
# 10  A crusty ciabatta bun is a flavorsome sponge f...
# 11  This is what put Ricobene&rsquo;s on the map: ...
# 12  This is what put Ricobene&rsquo;s on the map: ...
# 13  This is what put Ricobene&rsquo;s on the map: ...
# 14  This is what put Ricobene&rsquo;s on the map: ...
# 15  We didn&rsquo;t expect a <em>Man v. Food&ndash...
# 16  Luscious nuggets of white meat from the kitche...
# 17  With its toasted brioche, peppery pickled jala...
# 18  No condiments, no fuss, just saucy meatballs (...
# 19  The most famous deli sandwich in Chicago is al...
# 20  Cut in quarters and stabbed with cellophaned t...
# 21  The fritters of mashed chickpeas are perfectly...
# 22  In these parts, crab cakes are always a gamble...
# 23  A no-frills thrill, the schnitzel is a classic...
# 24  Dawali&rsquo;s filling shawarma escapes a comm...
# 25  Dawali&rsquo;s filling shawarma escapes a comm...
# 26  Not the gooiest but definitely the kickiest gr...
# 27  La Pane might be known for pizza, but it offer...
# 28  Sometimes you come across a sandwich with a co...
# 29  Sometimes you come across a sandwich with a co...
# ..                                                ...
# 31  Pastrami is the bacon of deli meats&mdash;a su...
# 32  This hulk&mdash;which stacks copious amounts o...
# 33  This hulk&mdash;which stacks copious amounts o...
# 34  Each element of this highfalutin deli delight&...
# 35  Two razor-thin fried plantains&mdash;crispy, n...
# 36  Any respectable diner offers this humblest of ...
# 37  A perpetually jammed workday lunch stop has no...
# 38  A perpetually jammed workday lunch stop has no...
# 39  A perpetually jammed workday lunch stop has no...
# 40  A perpetually jammed workday lunch stop has no...
# 41  Pierre Zimmermann claims to be a fourth-genera...
# 42  Briny lean brisket, kraut, and melted Gruy&egr...
# 43  Sweet figs, salt-speckled bread, and smoky Gou...
# 44  The silky smooth almond-date spread makes this...
# 45  Duck is not your typical sandwich meat, but Fi...
# 46  Not fair that Parisians are so famously skinny...
# 47  With chewy strips of preserved lemon rind, moi...
# 48  Caramelized chunks of dark and white meat chic...
# 49  Caramelized chunks of dark and white meat chic...
# 50  When a boneless chicken breast is dripping wit...
# 51  The generous application of muhammara&mdash;a ...
# 52  Could a sandwich sound more unsexy? Hardly. Bu...
# 53  The chalkboard menu is ambiguous about whether...
# 54  Who says veggie sandwiches are healthy? This b...
# 55  The success of this sandwich, a Cuban traditio...
# 56  Nestled within the freshest, chewiest pita poc...
# 57  Nothing quite satisfies the comfortfood hunger...
# 58  Proof positive that sandwiches have surpassed ...
# 59  Toni Cox spreads rich white bean hummus on a b...
# 60  The best thing about Phoebe&rsquo;s panini is ...
#
#                     address  \
# 0      2109 W. Chicago Ave.
# 1       800 W. Randolph St.
# 2          445 N. Clark St.
# 3             914 Noyes St.
# 4        825 W. Fulton Mkt.
# 5         100 E. Walton St.
# 6       1639 S. Wabash Ave.
# 7        2211 W. North Ave.
# 8        3619 W. North Ave.
# 9       3267 S. Halsted St.
# 10     2537 N. Kedzie Blvd.
# 11       252 W. 26th Street
# 12        271 N. Weber Road
# 13     5160 S. Pulaski Road
# 14     9135 W. 159th Street
# 15         3124 N. Broadway
# 16   3455 N. Southport Ave.
# 17      2657 N. Kedzie Ave.
# 18       1120 W. Grand Ave.
# 19    1141 S. Jefferson St.
# 20        333 E. Benton Pl.
# 21        1411 N. Wells St.
# 22       1747 N. Damen Ave.
# 23  3209 W. Irving Park Rd.
# 24       1625 N Halsted St.
# 25        4911 N Kedzie Ave
# 26        5347 N. Clark St.
# 27  2954 W. Irving Park Rd.
# 28         2945 N. Broadway
# 29               53 E. Lake
# ..                      ...
# 31    191 Skokie Valley Rd.
# 32      717 Maxwell Street.
# 33     3472 North Clark St.
# 34      1818 W. Wilson Ave.
# 35     2517 W. Division St.
# 36        218 W. Kinzie St.
# 37       400 N. LaSalle St.
# 38      131 S. Dearborn St.
# 39    180 W. Washington St.
# 40     233 N. Michigan Ave.
# 41        1547 N. Wells St.
# 42    415 N. Milwaukee Ave.
# 43       1840 N. Damen Ave.
# 44     1220 W. Webster Ave.
# 45     5357 N. Ashland Ave.
# 46    1834 W. Montrose Ave.
# 47         615 N. State St.
# 48          567 W. Lake St.
# 49       131 N. Clinton St.
# 50          241 N. York Rd.
# 51         1323 E. 57th St.
# 52          655 Forest Ave.
# 53        1816 N. Clark St.
# 54        100 S. Marion St.
# 55     26 E. Congress Pkwy.
# 56     2018 W. Chicago Ave.
# 57       25 E. Delaware Pl.
# 58          416 N. York St.
# 59     65 E. Washington St.
# 60         3351 N. Broadway
#
#                                              sandwich  \
# 0                                                 BLT
# 1                                       Fried Bologna
# 2                                   Woodland Mushroom
# 3                                          Roast Beef
# 4                                            PB&amp;L
# 5                         Belgian Chicken Curry Salad
# 6                                        Lobster Roll
# 7                                 Smoked Salmon Salad
# 8                                     Atomica Cemitas
# 9   Grilled Laughing Bird Shrimp and Fried Oyster ...
# 10                            Ham and Raclette Panino
# 11                                      Breaded Steak
# 12                                      Breaded Steak
# 13                                      Breaded Steak
# 14                                      Breaded Steak
# 15                                        The Hawkeye
# 16                                        Chicken Dip
# 17                               Wild Boar Sloppy Joe
# 18                                       Meatball Sub
# 19                                        Corned Beef
# 20                                        Turkey Club
# 21                                            Falafel
# 22                                          Crab Cake
# 23                                  Chicken Schnitzel
# 24                                           Shawarma
# 25                                           Shawarma
# 26                            Toasted Pimiento Cheese
# 27                                  Vegetarian Panino
# 28                                 Cali Ch&egrave;vre
# 29                                 Cali Ch&egrave;vre
# ..                                                ...
# 31                                           Pastrami
# 32                                          The Fredo
# 33                                          The Fredo
# 34                                         Smoked Ham
# 35                                           Jibarito
# 36                                   Shaved Prime Rib
# 37                    Serrano ham and Manchego cheese
# 38                    Serrano ham and Manchego cheese
# 39                    Serrano ham and Manchego cheese
# 40                    Serrano ham and Manchego cheese
# 41                                         Tuna Salad
# 42                                   Paramount Reuben
# 43                                       The Istanbul
# 44                                             B.A.D.
# 45                         Duck Confit and Mozzarella
# 46                                    Croque Monsieur
# 47                                     Green Garbanzo
# 48                                      The Hen House
# 49                                      The Hen House
# 50                                     Tuscan Chicken
# 51                                          The Marty
# 52                                          Whitefish
# 53             Oat Bread, Pecan Butter, and Fruit Jam
# 54                                   Cauliflower Melt
# 55                                             Cubano
# 56                                              Kufta
# 57                           Debbie&rsquo;s Egg Salad
# 58                                         Beef Curry
# 59                        Le V&eacute;g&eacute;tarien
# 60                                         The Gatsby
#
#                          restaurant                          full_address  \
# 0                       Old Oak Tap         2109 W. Chicago Ave., Chicago
# 1                         Au Cheval          800 W. Randolph St., Chicago
# 2                              Xoco             445 N. Clark St., Chicago
# 3                   Al&rsquo;s Deli               914 Noyes St., Evanston
# 4             Publican Qualty Meats           825 W. Fulton Mkt., Chicago
# 5   Hendrickx Belgian Bread Crafter            100 E. Walton St., Chicago
# 6                            Acadia          1639 S. Wabash Ave., Chicago
# 7                 Birchwood Kitchen           2211 W. North Ave., Chicago
# 8                    Cemitas Puebla           3619 W. North Ave., Chicago
# 9                              Nana          3267 S. Halsted St., Chicago
# 10                        Lula Cafe         2537 N. Kedzie Blvd., Chicago
# 11                 Ricobene&rsquo;s           252 W. 26th Street, Chicago
# 12                 Ricobene&rsquo;s        271 N. Weber Road, Bolingbrook
# 13                 Ricobene&rsquo;s         5160 S. Pulaski Road, Chicago
# 14                 Ricobene&rsquo;s    9135 W. 159th Street, Orland Hills
# 15                     Frog n Snail             3124 N. Broadway, Chicago
# 16           Crosby&rsquo;s Kitchen       3455 N. Southport Ave., Chicago
# 17              Longman &amp; Eagle          2657 N. Kedzie Ave., Chicago
# 18                             Bari           1120 W. Grand Ave., Chicago
# 19                    Manny&rsquo;s        1141 S. Jefferson St., Chicago
# 20                     Eggy&rsquo;s            333 E. Benton Pl., Chicago
# 21                    Old Jerusalem            1411 N. Wells St., Chicago
# 22       Mindy&rsquo;s HotChocolate           1747 N. Damen Ave., Chicago
# 23        Olga&rsquo;s Delicatessen      3209 W. Irving Park Rd., Chicago
# 24     Dawali Mediterranean Kitchen           1625 N Halsted St., Chicago
# 25     Dawali Mediterranean Kitchen            4911 N Kedzie Ave, Chicago
# 26                        Big Jones            5347 N. Clark St., Chicago
# 27                          La Pane      2954 W. Irving Park Rd., Chicago
# 28                         Pastoral             2945 N. Broadway, Chicago
# 29                         Pastoral                   53 E. Lake, Chicago
# ..                              ...                                   ...
# 31                 Max&rsquo;s Deli  191 Skokie Valley Rd., Highland Park
# 32       Lucky&rsquo;s Sandwich Co.          717 Maxwell Street., Chicago
# 33       Lucky&rsquo;s Sandwich Co.         3472 North Clark St., Chicago
# 34                  City Provisions          1818 W. Wilson Ave., Chicago
# 35       Papa&rsquo;s Cache Sabroso         2517 W. Division St., Chicago
# 36  Bavette&rsquo;s Bar &amp; Boeuf            218 W. Kinzie St., Chicago
# 37           Hannah&rsquo;s Bretzel           400 N. LaSalle St., Chicago
# 38           Hannah&rsquo;s Bretzel          131 S. Dearborn St., Chicago
# 39           Hannah&rsquo;s Bretzel        180 W. Washington St., Chicago
# 40           Hannah&rsquo;s Bretzel         233 N. Michigan Ave., Chicago
# 41                     La Fournette            1547 N. Wells St., Chicago
# 42                   Paramount Room        415 N. Milwaukee Ave., Chicago
# 43             Melt Sandwich Shoppe           1840 N. Damen Ave., Chicago
# 44       Floriole Cafe &amp; Bakery         1220 W. Webster Ave., Chicago
# 45      First Slice Pie Caf&eacute;         5357 N. Ashland Ave., Chicago
# 46                          Troquet        1834 W. Montrose Ave., Chicago
# 47                       Grahamwich             615 N. State St., Chicago
# 48                   Saigon Sisters              567 W. Lake St., Chicago
# 49                   Saigon Sisters           131 N. Clinton St., Chicago
# 50   Rosalia&rsquo;s Tuscan Chicken             241 N. York Rd., Elmhurst
# 51               Z&amp;H MarketCafe             1323 E. 57th St., Chicago
# 52       Market House on the Square          655 Forest Ave., Lake Forest
# 53       Elaine&rsquo;s Coffee Call            1816 N. Clark St., Chicago
# 54      Marion Street Cheese Market           100 S. Marion St., Oak Park
# 55                         Cafecito         26 E. Congress Pkwy., Chicago
# 56                         Chickpea         2018 W. Chicago Ave., Chicago
# 57           The Goddess and Grocer           25 E. Delaware Pl., Chicago
# 58                          Zenwich             416 N. York St., Elmhurst
# 59                  Toni Patisserie         65 E. Washington St., Chicago
# 60            Phoebe&rsquo;s Bakery             3351 N. Broadway, Chicago
#
#                                     formatted_address
# 0    2109 West Chicago Avenue, Chicago, IL 60622, USA
# 1    800 West Randolph Street, Chicago, IL 60607, USA
# 2      445 North Clark Street, Chicago, IL 60654, USA
# 3           914 Noyes Street, Evanston, IL 60201, USA
# 4      825 West Fulton Market, Chicago, IL 60607, USA
# 5      100 East Walton Street, Chicago, IL 60611, USA
# 6    1639 South Wabash Avenue, Chicago, IL 60616, USA
# 7      2211 West North Avenue, Chicago, IL 60647, USA
# 8      3619 West North Avenue, Chicago, IL 60647, USA
# 9   3267 South Halsted Street, Chicago, IL 60608, USA
# 10  2537 North Kedzie Boulevard, Chicago, IL 60647...
# 11       252 West 26th Street, Chicago, IL 60616, USA
# 12         271 Weber Road, Bolingbrook, IL 60490, USA
# 13    5160 South Pulaski Road, Chicago, IL 60632, USA
# 14  9135 West 159th Street, Orland Hills, IL 60487...
# 15        3124 North Broadway, Chicago, IL 60657, USA
# 16  3455 North Southport Avenue, Chicago, IL 60657...
# 17   2657 North Kedzie Avenue, Chicago, IL 60647, USA
# 18     1120 West Grand Avenue, Chicago, IL 60642, USA
# 19  1141 South Jefferson Street, Chicago, IL 60607...
# 20      333 East Benton Place, Chicago, IL 60601, USA
# 21    1411 North Wells Street, Chicago, IL 60610, USA
# 22    1747 North Damen Avenue, Chicago, IL 60647, USA
# 23  3209 West Irving Park Road, Chicago, IL 60618,...
# 24  1625 North Halsted Street, Chicago, IL 60614, USA
# 25   4911 North Kedzie Avenue, Chicago, IL 60625, USA
# 26    5347 North Clark Street, Chicago, IL 60640, USA
# 27  2954 West Irving Park Road, Chicago, IL 60618,...
# 28        2945 North Broadway, Chicago, IL 60657, USA
# 29        53 East Lake Street, Chicago, IL 60601, USA
# ..                                                ...
# 31  191 Skokie Valley Road, Highland Park, IL 6003...
# 32  717 West Maxwell Street, University of Illinoi...
# 33    3472 North Clark Street, Chicago, IL 60657, USA
# 34    1818 West Wilson Avenue, Chicago, IL 60640, USA
# 35  2517 West Division Street, Chicago, IL 60622, USA
# 36     218 West Kinzie Street, Chicago, IL 60654, USA
# 37   400 North LaSalle Street, Chicago, IL 60654, USA
# 38  131 South Dearborn Street, Chicago, IL 60603, USA
# 39  180 West Washington Street, Chicago, IL 60602,...
# 40  233 North Michigan Avenue, Chicago, IL 60601, USA
# 41    1547 North Wells Street, Chicago, IL 60610, USA
# 42  415 North Milwaukee Avenue, Chicago, IL 60654,...
# 43    1840 North Damen Avenue, Chicago, IL 60622, USA
# 44   1220 West Webster Avenue, Chicago, IL 60614, USA
# 45  5357 North Ashland Avenue, Chicago, IL 60640, USA
# 46  1834 West Montrose Avenue, Chicago, IL 60613, USA
# 47     615 North State Street, Chicago, IL 60611, USA
# 48       567 West Lake Street, Chicago, IL 60661, USA
# 49   131 North Clinton Street, Chicago, IL 60661, USA
# 50     241 North York Street, Elmhurst, IL 60126, USA
# 51      1323 East 57th Street, Chicago, IL 60637, USA
# 52      655 Forest Avenue, Lake Forest, IL 60045, USA
# 53    1816 North Clark Street, Chicago, IL 60614, USA
# 54   100 South Marion Street, Oak Park, IL 60302, USA
# 55   26 East Congress Parkway, Chicago, IL 60605, USA
# 56   2018 West Chicago Avenue, Chicago, IL 60622, USA
# 57     25 East Delaware Place, Chicago, IL 60611, USA
# 58     416 North York Street, Elmhurst, IL 60126, USA
# 59  65 East Washington Street, Chicago, IL 60602, USA
# 60        3351 North Broadway, Chicago, IL 60657, USA
#
# [61 rows x 6 columns]

# %% [markdown]
# If we need to set filters for different pieces of text, our scripts will get thrown off when they encounter mixed case characters. So lets convert all text in the columns to lowercase

# %%
# Now we want to apply the lowercase function called lower() across these columns in this list "col" I made
# This is good for mixed case words
# Applymap is useful to apply to row-wise AND column-wise (since multiple columns). 
# Apply is just for rows in one column
df_best_sws[cols] = df_best_sws[cols].applymap(lambda x: x.lower())
df_best_sws.head()
# Out:
#    rank           sandwich             restaurant  \
# 0     1                blt            old oak tap
# 1     2      fried bologna              au cheval
# 2     3  woodland mushroom                   xoco
# 3     4         roast beef        al&rsquo;s deli
# 4     5           pb&amp;l  publican qualty meats
#
#                                          description price  \
# 0  the b is applewood smoked&mdash;nice and snapp...    10
# 1  thought your bologna-eating days had retired w...     9
# 2  leave it to rick bayless and crew to come up w...  9.50
# 3  the francophile brothers behind this deli, whi...  9.40
# 4  when this place opened in february, it quickly...    10
#
#                 address      city         phone                   website  \
# 0  2109 w. chicago ave.   Chicago  773-772-0406          theoldoaktap.com
# 1   800 w. randolph st.   Chicago  312-929-4580       aucheval.tumblr.com
# 2      445 n. clark st.   Chicago  312-334-3688           rickbayless.com
# 3         914 noyes st.  Evanston           NaN               alsdeli.net
# 4    825 w. fulton mkt.   Chicago  312-445-8977  publicanqualitymeats.com
#
#                     full_address  \
# 0  2109 w. chicago ave., chicago
# 1   800 w. randolph st., chicago
# 2      445 n. clark st., chicago
# 3        914 noyes st., evanston
# 4    825 w. fulton mkt., chicago
#
#                                   formatted_address        lat        lng
# 0  2109 west chicago avenue, chicago, il 60622, usa  41.895734 -87.679960
# 1  800 west randolph street, chicago, il 60607, usa  41.884672 -87.647754
# 2    445 north clark street, chicago, il 60654, usa  41.890602 -87.630925
# 3         914 noyes street, evanston, il 60201, usa  42.058442 -87.684425
# 4    825 west fulton market, chicago, il 60607, usa  41.886637 -87.648553

# %% [markdown]
# ### 4. `groupby()`
#
# refers to a process involving one or more of the following steps
#
# __*Splitting*__ the data into groups based on some criteria
# __*Applying*__ a function to each group independently
# __*Combining*__ the results into a data structure
#
# Of these, the split step is the most straightforward. In fact, in many situations you may wish to split the data set into groups and do something with those groups yourself. In the apply step, we might wish to one of the following:
#
# __*Aggregation*__: computing a summary statistic (or statistics) about each group. Some examples:
#
# - Compute group sums or means
# - Compute group sizes / counts
#
# __*Transformation*__: perform some group-specific computations and return a like-indexed. Some examples:
#
# - Standardizing data (zscore) within group
# - Filling NAs within groups with a value derived from each group
#
# __*Filtration*__: discard some groups, according to a group-wise computation that evaluates True or False. Some examples:
#
# - Discarding data that belongs to groups with only a few members
# - Filtering out data based on the group sum or mean
#
# Some combination of the above: GroupBy will examine the results of the apply step and try to return a sensibly combined result if it doesn’t fit into either of the above two categories

# %%
# grouping by "price" just gives me data location
df_best_sws.groupby("price")

# %%
# create a mini data frame...aka a subsetted data frame
# np.mean (np = numpy) has you do array-wise computations, not element wise
# pd = pandas
# we want to compute the average of the rank column
# pd.Series is an array object that comes from pandas. Each column can be independently identified as a series object (vector or array)
# I want the mean to be computed, but I want the mean to be put into an array
def temp_func(mini_df):
    return pd.Series({"average_rank":np.mean(mini_df["rank"])})

# %%
df_best_sws[df_best_sws.price==7.5]
# Out:
#     rank    sandwich                  restaurant  \
# 32    27   the fredo  lucky&rsquo;s sandwich co.
# 33    27   the fredo  lucky&rsquo;s sandwich co.
# 58    48  beef curry                     zenwich
#
#                                           description  price  \
# 32  this hulk&mdash;which stacks copious amounts o...    7.5
# 33  this hulk&mdash;which stacks copious amounts o...    7.5
# 58  proof positive that sandwiches have surpassed ...    7.5
#
#                  address      city           phone            website  \
# 32   717 maxwell street.   Chicago  (312) 733-5700  luckysandwich.com
# 33  3472 north clark st.   Chicago  (773) 549-0665  luckysandwich.com
# 58       416 n. york st.  Elmhurst             NaN   eatmyzenwich.com
#
#                      full_address  \
# 32   717 maxwell street., chicago
# 33  3472 north clark st., chicago
# 58      416 n. york st., elmhurst
#
#                                     formatted_address        lat        lng
# 32  717 west maxwell street, university of illinoi...  41.864700 -87.645922
# 33    3472 north clark street, chicago, il 60657, usa  41.945241 -87.655353
# 58     416 north york street, elmhurst, il 60126, usa  41.910661 -87.939928

# %%
# Need to convert price to numeric FIRST
df_best_sws["price"] = df_best_sws.price.convert_objects(convert_numeric=True)
# Out:
# /Users/Gian/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app

# %%
df_best_sws.dtypes
# Out:
# rank                   int64
# sandwich              object
# restaurant            object
# description           object
# price                float64
# address               object
# city                  object
# phone                 object
# website               object
# full_address          object
# formatted_address     object
# lat                  float64
# lng                  float64
# dtype: object

# %%
# For each price level, I'm applying the average rank function on it
# This will show the average rank on every price level
# pd.cut will be a good function to break up by bins instead of individual prices
df_best_sws.groupby("price").apply(temp_func)
# Out:
#        average_rank
# price
# 4.50      16.000000
# 5.00      21.000000
# 5.49      18.600000
# 5.99      24.000000
# 6.00      31.750000
# 6.25      19.000000
# 6.50      47.000000
# 6.85      50.000000
# 7.00      35.666667
# 7.25      23.500000
# 7.50      34.000000
# 7.52      25.000000
# 7.95      34.000000
# 8.00      36.000000
# 8.75      49.000000
# 9.00      25.200000
# 9.40       4.000000
# 9.50       3.000000
# 9.75      32.000000
# 9.79      31.000000
# 10.00      7.000000
# 11.00     26.500000
# 11.50     18.000000
# 11.95     21.500000
# 12.95     28.000000
# 13.00     24.000000
# 14.00     13.000000
# 15.00     20.000000
# 16.00      7.000000
# 17.00     10.000000
# 21.00     30.000000

# %%
# create histogram that automatically creates bins for me
import matplotlib.pyplot as plt
# %pylab inline
df_best_sws.price.hist()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Graphing
# ### 1. `matplotlib`
# `matplotlib` provides tons of tools for creating line plots, image plots, and even some 3D plots. When you write scripts using these tools, you will need to import the desired functions.  There are a couple of common approaches.  The first is to import the specific functions you want using:
#
#     from matplotlib.pyplot import plot, subplot, figure, etc.
#
# An alternative that is also used quite often is:
#
#     import matplotlib.pyplot as plt
#
# Using this approach, you can refer to the plot commands through the `plt` name such as `plt.plot`.
#
#
# ### 2. `plot()`
#
# The **`plot`** command is the swiss army knife of plotting commands.  It defaults to creating line plots, but it is possible to control many different aspects of data display (marker types, color, transparency, etc.) through its key word arguments.

# %%
# This library is for plotting. Import plt function from matplotlib.pyplot library
import matplotlib.pyplot as plt
import numpy as np

# embed all plots within notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### line plot

# %% [markdown]
# #### plot against indices
#
# When calling **`plot`** with a single argument (in this case `sin(x)`), the values of the array are used as the y values, and the indices of the array (0, 1, 2, ...) are used as the x axis.

# %%
# np.linespace generates linear sequence of numbers from 0 to 2*pi in 50 increments
# then we plot a sin of this sequence of values of x
x = np.linspace(0, 2*np.pi, 50)
plt.plot(np.sin(x))
plt.show()

# %%
# ?np.linspace

# %% [markdown]
# When calling plot with two arguments, the first is used as the x value, and the second is used as the y value.

# %%
plot(x,sin(x))
plt.show()

# %% [markdown]
# #### multiple data sets
#
# Calling **`plot`** with multiple argument pairs results in multiple lines within a plot.

# %%
# Plotting multiple data sets and automatically does different colors
plot(x, sin(x), x, sin(2*x))
plt.show()

# %% [markdown]
# ### 3. launching `plot()` inline/separate window
# It is possible, however, to launch an external plot window from using the magic command **`%pylab qt`**. There are multiple benefits to external windows including much more interactive plots (zooming, panning, etc.).  You can use this window to experiment with the various toolbars.

# %%
# %pylab qt
plot(x, sin(x))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# To switch back to inline plots, use the magic command **`%pylab inline`**.

# %%
# %pylab inline
plot(x, sin(x))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 4. plot format strings
#
# If and x,y data pair is followed by a string, it is interpreted as a format string for the line that allows you to specify color, line type, and marker type.  To see a full list of options for format strings, type **`plot?`** at the prompt.

# %%
# This puts a triangle at each iteration/data point
# %pylab inline
plot(x, sin(x), 'r-^')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# o represents dots
plot(x, sin(x), 'b-o', x, sin(2*x), 'r-^')
plt.show()

# %% [markdown]
# ### 5. scatter plots
#
# The **`scatter`** function can create simple x, y scatter plots.

# %%
# this just shows a scatter plot of a sine wave
import numpy as np
x = np.linspace(0, 2*pi, 50)
y = sin(x)
scatter(x,y)
plt.show()

# %%
# Generate 200 random datas
x = randn(200)
y = randn(200)
size = rand(200) * 30
color = rand(200)
scatter(x, y, size, color)
colorbar()
plt.show()

# %% [markdown]
# ### 6. multiple plot windows
#
# The **`figure`** function will create new plot windows (when not in the inline plot display mode in notebooks).  In notebooks, it simply creates two separate plots.

# %%
# %pylab qt
t = np.linspace(0, 2*pi, 50)
x = sin(t)
y = cos(t)

# create the first window
figure()
plot(x)
plt.show()

# create the second window.
figure()
plot(y)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['size']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ### 7. multiple plots in one window
#
# The **`subplot`** function allows you to position two separate plots within a single plot window.

# %%
# subplot stores multiple plots into a plt.show() so you can see all plots at once
# %pylab inline
x = array([1,2,3,2,1])
y = array([1,3,2,3,1])

subplot(3,1,1)
plot(x)

subplot(3,1,2)
plot(y)

subplot(3,1,3)
plot(x)

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 8. `legend`
#
# The **`legend`** function will add a legend to plots, using the specified `label` keyword argument that was passed into each plot function.

# %%
# Provides a legend AFTER you define the labels
plot(sin(x), label='sin')
plot(cos(x), label='cos')
legend()
plt.show()

# %% [markdown]
# Here is an example where we have three lines, but have only labeled two.  **`legend`** is smart enough to only put the labeled lines into the legend.

# %%
# Legend will only show for labels you created
plot(sin(x), label='sin')
plot(sin(2*x))
plot(cos(x), label='cos')
legend()
plt.show()

# %% [markdown]
# If the plot functions have not assigned a label to the lines, then you can pass a list of labels to the **`legend`**.  The labels are assigned to the data sets in the same order they were added to the plot.

# %%
# Shows legend by putting data into legend
plot(sin(x))
plot(cos(x))
legend(['sin', 'cos'])
plt.show()

# %% [markdown]
# ### 9. titles and grid

# %%
# How to create x label, y label, and title
plot(x, sin(x))
xlabel('radians')
ylabel('amplitude', fontsize='large')
title('Sin(x)')
plt.show()

# %% [markdown]
# ### 10. histograms
#
# **`hist`** will create a histogram with 10 bins by default.  This can be changed by specifying the `bins` keyword argument.
#
# Note that matplotlib's `hist` function can be slow on large data sets.  In these cases, it can be beneficial to use the `scipy.stats.histogram` method which is faster.  However, it only does the calculations. It'll be up to you to make the plot from the returned values.

# %%
# Generates 1000 random variables normally distributed with a mean of 0. SHOWS underlying data too
# You can set a seed
seed(13)
hist(randn(1000))
# Out:
# (array([   1.,    8.,   55.,  127.,  261.,  266.,  193.,   71.,   14.,    4.]),
#  array([-3.90030855, -3.15202226, -2.40373598, -1.65544969, -0.9071634 ,
#         -0.15887711,  0.58940918,  1.33769547,  2.08598176,  2.83426805,
#          3.58255434]),
#  <a list of 10 Patch objects>)

# %%
# Does not show underlying data
hist(randn(1000))
plt.show()

# %%
# Plots multiple histograms together
hist(randn(1000), 30)
hist(randn(100), 20)
plt.show()

# %% [markdown]
# ### 11. `seaborn`
#
# The `seaborn` library can make your graphs look better. You can compare this to `ggplot`
#
# To install this library run-

# %%
# shows progress of install
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.7.0.tar.gz (154kB)
#     100% |████████████████████████████████| 163kB 37kB/s
# Building wheels for collected packages: seaborn
# done
#   Stored in directory: /Users/Gian/Library/Caches/pip/wheels/e0/94/01/731d82dc437e1c8b65130956028f3fe693943c3e499a676dc9
# Successfully built seaborn
# Installing collected packages: seaborn
# Successfully installed seaborn-0.7.0
# You are using pip version 8.1.1, however version 8.1.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import seaborn as sns

# %%
hist(randn(1000))
plt.show()

# %%
hist(randn(1000), 30)
hist(randn(100), 20)
plt.show()

# %% [markdown]
# ## Exercises!
#
# Run the following line before you start creating plots.

# %%
aapl_df["Date"] = pd.to_datetime(aapl_df.Date)

# %% [markdown]
# This will convert the Date column of your data frame into a date time object, which allows `pandas` and `python` to provide
# - chronological ordering
# - derived variables such as week of year, weekday, isweekday, isweekend, day of week etc.
# - this also allows you to fit splines/interpolate data
#
# ### Q1.
# We combined all the data for `aapl` in the first section. Lets try to plot a few columns.
# - plot `Date` v/s `Adj Close`
# - plot `Date` v/s `High` & `Low` (in one graph, with different colors)
# - plot `Date` v/s difference between `High` & `Low`
#
# ### Q2.
# Is there a differnce in the trip times between `Customers` and `Subscribers` in the Divvy Dataset?
# - Provided descriptive statistics for each segment

# %%
# Q1
aapl_df.head()
# Out:
#         Date        Open        High         Low       Close    Volume  \
# 0 2015-10-21  114.000000  115.580002  113.699997  113.760002  41795200
# 1 2015-10-20  111.339996  114.169998  110.820000  113.769997  48778800
# 2 2015-10-19  110.800003  111.750000  110.110001  111.730003  29606100
# 3 2015-10-16  111.779999  112.000000  110.529999  111.040001  38236300
# 4 2015-10-15  110.930000  112.099998  110.489998  111.860001  37341000
#
#     Adj Close
# 0  113.760002
# 1  113.769997
# 2  111.730003
# 3  111.040001
# 4  111.860001

# %%
plot(aapl_df['Date'], aapl_df['Adj Close'])
xlabel('Date', fontsize='large')
ylabel('Adj Close', fontsize='large')
title('Q1 Plot Date vs Adj Close')

# %%
# Plot Date vs High, and label it HIGH. Then do the same for Date vs Low
plot(aapl_df['Date'], aapl_df['High'], label = 'HIGH','b')
plot(aapl_df['Date'], aapl_df['Low'], label = 'LOW','r')

# Label axis
xlabel('Date', fontsize='large')
ylabel('High vs Low', fontsize='large')
title('Q1 Plot Date vs High & Low')

# Show Legend
legend()

# Plot everything together
plt.show()

# %%
# Plot Date vs High, and label it HIGH. Then do the same for Date vs Low
difference_High_Low = aapl_df['High'] - aapl_df['Low']

plot(aapl_df['Date'], difference_High_Low)

# Label axis
xlabel('Date', fontsize='large')
ylabel('High - Low', fontsize='large')
title('Q1 Plot Date vs Difference between High & Low')

# Plot everything together
plt.show()

# %%
# Q2
df_divvy.head()
# Out:
#    trip_id         starttime          stoptime  bikeid  tripduration  \
# 0     4118  2013-06-27 12:11  2013-06-27 12:16     480           316
# 1     5883  2013-06-28 12:55  2013-06-28 13:18     176          1368
# 2    42757  2013-07-09 19:06  2013-07-09 19:31     373          1480
# 3    42759  2013-07-09 19:07  2013-07-09 19:31      13          1469
# 4    48467  2013-07-11 12:24  2013-07-11 12:46     735          1330
#
#    from_station_id      from_station_name  to_station_id  \
# 0               85  Michigan Ave & Oak St             28
# 1               85  Michigan Ave & Oak St             28
# 2               85  Michigan Ave & Oak St             28
# 3               85  Michigan Ave & Oak St             28
# 4               85  Michigan Ave & Oak St             28
#
#               to_station_name  usertype      ...       dpcapacity_x  \
# 0  Larrabee St & Menomonee St  Customer      ...                 15
# 1  Larrabee St & Menomonee St  Customer      ...                 15
# 2  Larrabee St & Menomonee St  Customer      ...                 15
# 3  Larrabee St & Menomonee St  Customer      ...                 15
# 4  Larrabee St & Menomonee St  Customer      ...                 15
#
#    landmark_x  online date_x id_y                      name_y  latitude_y  \
# 0          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
# 1          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
# 2          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
# 3          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
# 4          42      6/28/2013   28  Larrabee St & Menomonee St    41.91468
#
#    longitude_y  dpcapacity_y landmark_y  online date_y
# 0    -87.64332            15        282      6/28/2013
# 1    -87.64332            15        282      6/28/2013
# 2    -87.64332            15        282      6/28/2013
# 3    -87.64332            15        282      6/28/2013
# 4    -87.64332            15        282      6/28/2013
#
# [5 rows x 26 columns]

# %%
df_divvy_customers = df_divvy[df_divvy.usertype=='Customer']
df_divvy_subscriber = df_divvy[df_divvy.usertype=='Subscriber']

# %%
np.mean(df_divvy_customers['tripduration'])

# %%
def descriptive_statistics(mini_df):
    return mini_df.describe()

df_divvy.groupby("usertype").apply(descriptive_statistics)["tripduration"]
